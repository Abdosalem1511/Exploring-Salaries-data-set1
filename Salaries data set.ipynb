# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the salaries dataset
salaries_df = pd.read_csv('Salaries.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-4d5a0595225e> in <cell line: 2>()
#       1 # Load the salaries dataset
# ----> 2 salaries_df = pd.read_csv('Salaries.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
# Basic Data Exploration
num_rows = salaries_df.shape[0]
num_cols = salaries_df.shape[1]
data_types = salaries_df.dtypes
missing_values = salaries_df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c5f970a08b67> in <cell line: 2>()
#       1 # Basic Data Exploration
# ----> 2 num_rows = salaries_df.shape[0]
#       3 num_cols = salaries_df.shape[1]
#       4 data_types = salaries_df.dtypes
#       5 missing_values = salaries_df.isnull().sum()
#
# NameError: name 'salaries_df' is not defined

# %%
# Descriptive Statistics
mean_salary = salaries_df['TotalPay'].mean()
median_salary = salaries_df['TotalPay'].median()
mode_salary = salaries_df['TotalPay'].mode().values[0]
min_salary = salaries_df['TotalPay'].min()
max_salary = salaries_df['TotalPay'].max()
salary_range = max_salary - min_salary
salary_std = salaries_df['TotalPay'].std()

# %%
# Data Cleaning
# Handle missing values by dropping rows with missing values
salaries_df.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-ba35dd62b055> in <cell line: 3>()
#       1 # Data Cleaning
#       2 # Handle missing values by dropping rows with missing values
# ----> 3 salaries_df.dropna(inplace=True)
#
# NameError: name 'salaries_df' is not defined

# %%
# Basic Data Visualization
plt.hist(salaries_df['TotalPay'], bins=20)
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.title('Distribution of Salaries')
plt.show()

department_counts = salaries_df['JobTitle'].value_counts().head(10)
plt.pie(department_counts, labels=department_counts.index, autopct='%1.1f%%')
plt.title('Proportion of Employees in Different Departments')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-bf2aea2dc22e> in <cell line: 2>()
#       1 # Basic Data Visualization
# ----> 2 plt.hist(salaries_df['TotalPay'], bins=20)
#       3 plt.xlabel('Salary')
#       4 plt.ylabel('Frequency')
#       5 plt.title('Distribution of Salaries')
#
# NameError: name 'salaries_df' is not defined

# %%
# Grouped Analysis
grouped_data = salaries_df.groupby('Year').mean()
average_salaries_by_year = grouped_data['TotalPay']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3e51d2e541bd> in <cell line: 2>()
#       1 # Grouped Analysis
# ----> 2 grouped_data = salaries_df.groupby('Year').mean()
#       3 average_salaries_by_year = grouped_data['TotalPay']
#
# NameError: name 'salaries_df' is not defined

# %%
# Simple Correlation Analysis
correlation = salaries_df['TotalPay'].corr(salaries_df['BasePay'])
plt.scatter(salaries_df['BasePay'], salaries_df['TotalPay'])
plt.xlabel('Base Pay')
plt.ylabel('Salary')
plt.title('Correlation between Base Pay and Salary')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-2950627e3189> in <cell line: 2>()
#       1 # Simple Correlation Analysis
# ----> 2 correlation = salaries_df['TotalPay'].corr(salaries_df['BasePay'])
#       3 plt.scatter(salaries_df['BasePay'], salaries_df['TotalPay'])
#       4 plt.xlabel('Base Pay')
#       5 plt.ylabel('Salary')
#
# NameError: name 'salaries_df' is not defined
